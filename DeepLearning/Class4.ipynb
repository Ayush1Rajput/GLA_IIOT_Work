# %% [markdown]
# # Overfitting
# 1. L1, L2 Regularization
# 2. Dropout layer
# 3. Early Stopping

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import warnings

import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1500, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step

# %% [markdown]
# ## Early Stopping

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1500, callbacks=callback)
# Out:
# Epoch 1/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6250 - loss: 0.6812 - val_accuracy: 0.3000 - val_loss: 0.7153
# Epoch 2/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.6779 - val_accuracy: 0.2500 - val_loss: 0.7157
# Epoch 3/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6289 - loss: 0.6721 - val_accuracy: 0.3500 - val_loss: 0.7159
# Epoch 4/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6367 - loss: 0.6738 - val_accuracy: 0.3500 - val_loss: 0.7167
# Epoch 5/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6055 - loss: 0.6801 - val_accuracy: 0.4000 - val_loss: 0.7163
# Epoch 6/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6055 - loss: 0.6744 - val_accuracy: 0.4000 - val_loss: 0.7161
# Epoch 7/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6586 - loss: 0.6683 - val_accuracy: 0.4000 - val_loss: 0.7164
# Epoch 8/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6602 - loss: 0.6683 - val_accuracy: 0.3500 - val_loss: 0.7163
# Epoch 9/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6469 - loss: 0.6719 - val_accuracy: 0.2500 - val_loss: 0.7158
# Epoch 10/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6172 - loss: 0.6727 - val_accuracy: 0.2500 - val_loss: 0.7155
# Epoch 11/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6352 - loss: 0.6703 - val_accuracy: 0.2500 - val_loss: 0.7154
# Epoch 12/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6273 - loss: 0.6708 - val_accuracy: 0.2500 - val_loss: 0.7155
# Epoch 13/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6586 - loss: 0.6688 - val_accuracy: 0.3000 - val_loss: 0.7161
# Epoch 14/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5953 - loss: 0.6712 - val_accuracy: 0.3000 - val_loss: 0.7167
# Epoch 15/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6086 - loss: 0.6664 - val_accuracy: 0.4000 - val_loss: 0.7184
# Epoch 16/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5969 - loss: 0.6608 - val_accuracy: 0.3000 - val_loss: 0.7194
# Epoch 17/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6008 - loss: 0.6651 - val_accuracy: 0.3000 - val_loss: 0.7194
# Epoch 18/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5969 - loss: 0.6617 - val_accuracy: 0.2500 - val_loss: 0.7197
# Epoch 19/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6383 - loss: 0.6614 - val_accuracy: 0.2500 - val_loss: 0.7197
# Epoch 20/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6187 - loss: 0.6640 - val_accuracy: 0.2500 - val_loss: 0.7191
# Epoch 21/1500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5953 - loss: 0.6667 - val_accuracy: 0.3000 - val_loss: 0.7187
# Epoch 21: early stopping
